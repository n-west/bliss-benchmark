# %%
import hdf5plugin
import h5py
import blimpy as bl
# %matplotlib widget
import matplotlib.pyplot as plt

# %%
# !ls
# Out:
#  01-generate_simple_injection_for_snr
#  bliss-benchmark
#  data
# 'doppler_smear_test_gpu_offset_1000_injected_f=6003329687.5_drift=3.4.rawspec.0000.h5'
# 'doppler_smear_test_gpu_offset_1000_injected_f=6003329687.5.rawspec.0000.h5'
#  report1.qdstrm
#  requirements.txt
#  run-bliss-onh5.ipynb
# 'setigen create.ipynb'
#  test_v_std0.001_pols1.0000.raw
#  view_bllimpy.ipynb
#  view_raw.ipynb
#  voltage_gen.py

# %%
# f = "/home/nathan/datasets/siggen/raw_files/"

# fil = h5py.File('doppler_smear_test_gpu_offset_1000.rawspec.0000.h5')
raw = bl.GuppiRaw('/home/nathan/datasets/siggen/raw_files/doppler_smear_test_gpu_offset_1000_injected_f=6003329687.5_drift=0.34.0000.raw')

# /home/nathan/datasets/siggen/raw_files/doppler_smear_test_gpu_offset_1000.0001.raw

# %%
raw.plot_spectrum()

# %%
header, data = raw.read_next_data_block()

# %%
# for k,v in header.items():
#     print(f"{k}\t\t::\t{v}")

# %%
data.shape
# Out:
# (1, 67108864, 1)

# %%
plt.figure()
plt.plot(data[0,:5000:2,0])

plt.figure()
_ = plt.psd(data[0,::2,0], NFFT=8192)

plt.figure()
_ = plt.psd(data[0,1::2,0], NFFT=8192)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
data = fil["data"]
print(data.shape)

data_attrs = data.attrs
for k in data_attrs:
    print(f"{k} :: {data_attrs[k]}")

# %% [markdown]
# Voyager GBT md:
# ```
# DIMENSION_LABELS :: ['time' 'feed_id' 'frequency']
# az_start :: 0.0
# data_type :: 1
# fch1 :: 8421.38671875
# foff :: -2.7939677238464355e-06
# machine_id :: 20
# nbits :: 32
# nchans :: 1048576
# nifs :: 1
# source_name :: VOYAGER-1
# src_dej :: 12.403781666666667
# src_raj :: 17.211244722222222
# telescope_id :: 6
# tsamp :: 18.253611007999982
# tstart :: 59046.92634259259
# za_start :: 0.0
# ```

# %%
data_arr = data[:,0,0:int(2**20)]

# %%
import numpy as np

# %%
plt.figure()
plt.plot(np.log10(np.sum(data_arr, 0)))

plt.figure()
plt.plot(((data_arr[2,:])))

# %%
(6.685e5-0) / np.std(data[:,0,250000:400000])

# %%
plt.figure()
plt.imshow(10*np.log10(data_arr[:,:]), aspect="auto")

# %%
5998.53801727-5998.53515625
