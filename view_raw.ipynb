# %%
import hdf5plugin
import h5py
# %matplotlib widget
import matplotlib.pyplot as plt

# %%
# !ls
# Out:
#  01-generate_simple_injection_for_snr  'setigen create.ipynb'
#  bliss-benchmark		        test_v_std0.001_pols1.0000.raw
#  report1.qdstrm			        test_v_std0.001_pols1.rawspec.0000.h5
#  requirements.txt		        view_bllimpy.ipynb
#  run-bliss-onh5.ipynb		        view_raw.ipynb

# %%
fil = h5py.File('test_v_std0.001_pols1.rawspec.0000.h5')

# %%
1048576 * 2
# Out:
# 2097152

# %%
data = fil["data"]
print(data.shape)

data_attrs = data.attrs
for k in data_attrs:
    print(f"{k} :: {data_attrs[k]}")
# Out:
# (192, 1, 1048576)
# DIMENSION_LABELS :: ['time' 'feed_id' 'frequency']
# az_start :: 0.0
# data_type :: 1
# fch1 :: 5998.53515625
# foff :: 2.7939677238464355e-06
# ibeam :: -1
# machine_id :: 20
# nbeams :: 1
# nbits :: 32
# nchans :: 1048576
# nfpc :: 1048576
# nifs :: 1
# rawdatafile :: b'test_v_std0.001_pols1.0000.raw'
# source_name :: b'TMC1'
# src_dej :: 25.6911
# src_raj :: 4.696053333333333
# telescope_id :: 6
# tsamp :: 0.357913941333333
# tstart :: 59114.183657407404
# za_start :: 0.0

# %% [markdown]
# Voyager GBT md:
# ```
# DIMENSION_LABELS :: ['time' 'feed_id' 'frequency']
# az_start :: 0.0
# data_type :: 1
# fch1 :: 8421.38671875
# foff :: -2.7939677238464355e-06
# machine_id :: 20
# nbits :: 32
# nchans :: 1048576
# nifs :: 1
# source_name :: VOYAGER-1
# src_dej :: 12.403781666666667
# src_raj :: 17.211244722222222
# telescope_id :: 6
# tsamp :: 18.253611007999982
# tstart :: 59046.92634259259
# za_start :: 0.0
# ```

# %%
import numpy as np

# %%
plt.figure()
plt.plot((np.sum(data[:,0,:], 0)))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.std(data[:,0,200000:350000])
# Out:
# 1350.7488

# %%
plt.figure()
plt.imshow(10*np.log10(data[:,0,:]), aspect="auto")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
5998.53801727-5998.53515625
# Out:
# 0.002861019999727432
