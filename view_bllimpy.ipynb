# %%
import blimpy as bl
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
wf = bl.Waterfall('test_v_std0.001_pols1.rawspec.0000.h5')

plt.figure(figsize=(10, 6))
wf.plot_waterfall()
plt.show()

# %%
wf.data.shape
# Out:
# (192, 1, 1048576)

# %%
wf.freqs
# Out:
# array([5998.53515625, 5998.53515904, 5998.53516184, ..., 6001.46483537,
#        6001.46483816, 6001.46484096])

# %%
5998.53801727-5998.53515625
# Out:
# 0.002861019999727432
