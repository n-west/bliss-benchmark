# %%
import blimpy as bl
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
# wf = bl.Waterfall('doppler_smear_test_gpu_offset_1000.rawspec.0000.h5')
wf = bl.Waterfall('doppler_smear_test_gpu_offset_1000_injected_f=6000400000.0.rawspec.0000.h5')

plt.figure(figsize=(10, 6))
wf.plot_waterfall()
plt.show()

plt.figure(figsize=(10, 6))
wf.plot_waterfall(f_start=6000.3995, f_stop=6000.4005)
plt.show()

plt.figure(figsize=(10, 6))
wf.plot_waterfall(f_start=6000 - 0.4005, f_stop=6000 - 0.3995)
plt.show()

# %%
help(wf.plot_waterfall)
# Out:
# Help on method plot_waterfall in module blimpy.plotting.plot_waterfall:
#
# plot_waterfall(f_start=None, f_stop=None, if_id=0, logged=True, cb=True, MJD_time=False, **kwargs) method of blimpy.waterfall.Waterfall instance
#     Plot waterfall of data
#
#     Args:
#         f_start (float): start frequency, in MHz
#         f_stop (float): stop frequency, in MHz
#         logged (bool): Plot in linear (False) or dB units (True),
#         cb (bool): for plotting the colorbar
#         kwargs: keyword args to be passed to matplotlib imshow()

# %%
wf.data.shape

# %%
wf.freqs

# %%
5998.53801727-5998.53515625
